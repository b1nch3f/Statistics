# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/county.csv')

# %% [markdown]
# ## Observations
# ## Variables
#     1. Categorial / Qualitative
#         a. Nominal
#         b. Ordinal
#     2. Numerical / Quantitative
#         a. Discrete
#         b. Continuous
# ## Data Matrices

# %%
df.head()
# Out:
#              name    state   pop2000  pop2010   pop2017  pop_change  poverty  \
# 0  Autauga County  Alabama   43671.0    54571   55504.0        1.48     13.7
# 1  Baldwin County  Alabama  140415.0   182265  212628.0        9.19     11.8
# 2  Barbour County  Alabama   29038.0    27457   25270.0       -6.22     27.2
# 3     Bibb County  Alabama   20826.0    22915   22668.0        0.73     15.2
# 4   Blount County  Alabama   51024.0    57322   58013.0        0.68     15.6
#
#    homeownership  multi_unit  unemployment_rate metro    median_edu  \
# 0           77.5         7.2               3.86   yes  some_college
# 1           76.7        22.6               3.99   yes  some_college
# 2           68.0        11.1               5.90    no    hs_diploma
# 3           82.9         6.6               4.39   yes    hs_diploma
# 4           82.0         3.7               4.02   yes    hs_diploma
#
#    per_capita_income  median_hh_income smoking_ban
# ...

# %% [markdown]
# ## Relationship between variables
#     1. Associated variables / Dependent variables
#         a. Positive association
#         b. Negative association
#     2. Independent variables

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(data=df[['homeownership', 'pop_change']], x="pop_change", y="homeownership")
# Out:
# <Axes: xlabel='pop_change', ylabel='homeownership'>

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(data=df[['homeownership', 'multi_unit']], x="multi_unit", y="homeownership")
# Out:
# <Axes: xlabel='multi_unit', ylabel='homeownership'>

# %% [markdown]
# ## Explanatory and Response variables

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(data=df[['pop_change', 'median_hh_income']], x="median_hh_income", y="pop_change")
# Out:
# <Axes: xlabel='median_hh_income', ylabel='pop_change'>

# %% [markdown]
# ## Studies
#     1. Observational
#     2. Experimental
#         a. Randomized experiment

# %% [markdown]
# $\text{Association} \neq \text{Causation}$
